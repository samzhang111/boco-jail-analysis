# %% [markdown]
# We received all of the transient booking records from the Boulder County Sheriff's office from 2000-2016. They were sent with the following notes:
#
# * The data provided may not have all the fields complete due to old system conversion to new.
# * The request asked to match the data elements which are available from the “Public” tool, which includes associated charges, and to provide the data in an Excel format. To meet both these expectations required resolving a “many-to-one” problem (many charges to one offender) which results in there potentially being multiple Excel “Row” records for each booking number
#
# Now we will explore the shape of this data, and join it with the raw jail listings.
#
# Several goals of this process are to:
# * Flatten the booking records so that a single person getting booked is a single row
# * Add a column for whether or not that person is transient

# %%
import pandas as pd

df_sheriff = pd.read_excel('../data/transient-bookings-records.xlsx')

# %%
pd.set_option("display.max_columns", 100)

# %%
df_bookings = pd.read_csv('../data/all-bookings-with-antihomeless-charges.csv')

# %%
print('''The sheriff dataset has {} rows.'''.format(df_sheriff.shape[0]))

df_sheriff.head(3)
# Out:
# The sheriff dataset has 54469 rows.
#    Booking Number                   Name Address  City State  ZIP Code Race  \
# 0              58     SAUL,KENNETH BRETT     NaN   NaN    CO       NaN    W
# 1              58     SAUL,KENNETH BRETT     NaN   NaN    CO       NaN    W
# 2              85  MORIN,ARISTEO CULONGO     NaN  NONE    CO       NaN    W
#
#   Sex        DOB Booking Date  Booking Time Facility Location  \
# 0   M 1975-10-19   2000-01-02           245      NaN      NaN
# 1   M 1975-10-19   2000-01-02           245      NaN      NaN
# 2   M 1957-09-10   2000-01-03            46      NaN      NaN
#
#   Arresting Agency          Charge                 Title Charge Level
# 0             LOPD    18  3    208  RECKLESS ENDAGERMENT           M3
# 1             LOPD  16  11   502.1  FTC: FTC VIOLATION O            X
# 2             LFPD    18  5    113    CRIM IMPERSONATION           F6

# %%
# These charge levels are explained here: http://www.mtnlegal.com/2012/10/07/guide-to-criminal-penalties-in-colorado/

df_sheriff['Charge Level'].value_counts()
# Out:
# MO    17985
# X      8256
# M      4648
# M2     4486
# M3     3752
# M1     2950
# F4     2839
# F5     2134
# F6     1730
# F      1581
# P1     1111
# P2     1087
# F3     1062
# T       541
# F2      123
# F1       37
# I         3
# Name: Charge Level, dtype: int64

# %%
df_bookings.head(3)
# Out:
#                    Name  Booking No               Booked Location         DOB  \
# 0  ARELLANO-ORDAZ,SIMON     1106625  2011-08-09 22:20:00   BJ INW  1988-04-10
# 1  ARELLANO-ORDAZ,SIMON     1106625  2011-08-09 22:20:00   BJ INW  1988-04-10
# 2  ARELLANO-ORDAZ,SIMON     1106625  2011-08-09 22:20:00   BJ INW  1988-04-10
#
#   Race Sex    Case No Arresting Agency  \
# 0    W   M  110010043       BOULDER PD
# 1    W   M  110010043       BOULDER PD
# 2    W   M  110010043       BOULDER PD
#
#                                      Charge Arrest Date           charge_text  \
# 0  18-18-405(2)(A)(I). SALE/MFG/DIST/CONT S  2011-08-09  SALE/MFG/DIST/CONT S
# 1             18-6-401(7)(B)(I) CHILD ABUSE  2011-08-09           CHILD ABUSE
# 2          42-2-101(1) DRIVING WITHOUT A VA  2011-08-09  DRIVING WITHOUT A VA
#
#    legal_code_parts  legal_code_no_1  legal_code_no_2  legal_code_no_3  \
# 0  (18, 18, 405, 2)             18.0             18.0            405.0
# 1   (18, 6, 401, 7)             18.0              6.0            401.0
# 2   (42, 2, 101, 1)             42.0              2.0            101.0
#
#    legal_code_no_4  camping    fta    ftc         booking_time  boulder  \
# 0              2.0    False  False  False  2011-08-09 22:20:00    False
# 1              7.0    False  False  False  2011-08-09 22:20:00    False
# 2              1.0    False  False  False  2011-08-09 22:20:00    False
#
#    urination  vehicle_as_residence  public_obstruct  public_trespass  begging  \
# 0      False                 False            False            False    False
# 1      False                 False            False            False    False
# 2      False                 False            False            False    False
#
#    antihomeless  smoking
# 0         False    False
# 1         False    False
# 2         False    False

# %%
df_sheriff_by_person = df_sheriff.groupby('Booking Number').first()
df_bookings_by_person = df_bookings.groupby('Booking No').first()

# %%
df_bookings_by_person['any_antihomeless'] = df_bookings.groupby('Booking No').antihomeless.any()

# %%
antihomeless_columns =  ["smoking", "camping", "urination", "vehicle_as_residence", "public_obstruct", "public_trespass", "begging"]

# %%
df_bookings_by_person_antihomeless = df_bookings.groupby('Booking No')[antihomeless_columns].any()

# %%
df_bookings_by_person = pd.concat([df_bookings_by_person, df_bookings_by_person_antihomeless], axis=1)

# %%
df_bookings_by_person.drop([
        'Charge', 'charge_text', 'legal_code_parts', 'legal_code_no_1', 'legal_code_no_2', 'legal_code_no_3',
        'legal_code_no_4'
    ], axis=1, inplace=True)

# %%
print('''Unique booking ids in

transient dataset: {}
overall dataset: {}'''.format(
        df_sheriff_by_person.shape[0],
        df_bookings_by_person.shape[0]
))
# Out:
# Unique booking ids in
#
# transient dataset: 21962
# overall dataset: 167633

# %%
df_bookings_sheriff = pd.merge(df_bookings_by_person, df_sheriff_by_person, how='left', left_index=True, right_index=True, suffixes=('', '_s'))

# %%
print('''The merged column has {} rows.

{} of the rows are from the transient table
'''.format(
        df_bookings_sheriff.shape[0], 
        df_bookings_sheriff['Name_s'].count()
    )
)
# Out:
# The merged column has 167633 rows.
#
# 21895 of the rows are from the transient table

# %% [markdown]
# Not too bad. We lost 67 records between the two datasets.

# %%
df_bookings_sheriff.head()
# Out:
#                              Name               Booked Location         DOB  \
# Booking No
# 1                  HOOD,AARON JAY  2000-01-01 02:12:00           1975-10-08
# 2                LAWYER,KENNETH A  2000-01-01 04:01:00           1958-09-29
# 3           AGUILAR TORRES,MIGUEL  2000-01-01 03:11:00           1972-11-14
# 4             JUDD,OLIVER RANDALL  2000-01-01 01:25:00           1953-06-07
# 5            WINTER,STEPHEN SHANE  2000-01-01 03:49:00           1961-09-09
#
#            Race Sex    Case No        Arresting Agency Arrest Date  camping  \
# Booking No
# 1             W   M  991126052  UNIVERSITY OF COLORADO  1999-12-31    False
# 2             W   M  991001313         JAIL MITTS ONLY  2000-01-16    False
# 3             W   M  991126053  UNIVERSITY OF COLORADO  1999-12-31    False
# 4             W   M  991031932              BOULDER PD  1999-12-31    False
# 5             W   M  991102428             LONGMONT PD  1999-12-31    False
#
#               fta    ftc         booking_time  boulder  urination  \
# Booking No
# 1            True  False  2000-01-01 02:12:00    False      False
# 2           False  False  2000-01-01 04:01:00    False      False
# 3           False  False  2000-01-01 03:11:00    False      False
# 4           False  False  2000-01-01 01:25:00    False      False
# 5           False  False  2000-01-01 03:49:00    False      False
#
#             vehicle_as_residence  public_obstruct  public_trespass  begging  \
# Booking No
# 1                          False            False            False    False
# 2                          False            False            False    False
# 3                          False            False            False    False
# 4                          False            False            False    False
# 5                          False            False            False    False
#
#             antihomeless  smoking  any_antihomeless  smoking  camping  \
# Booking No
# 1                  False    False             False    False    False
# 2                  False    False             False    False    False
# 3                  False    False             False    False    False
# 4                  False    False             False    False    False
# 5                  False    False             False    False    False
#
#             urination  vehicle_as_residence  public_obstruct  public_trespass  \
# Booking No
# 1               False                 False            False            False
# 2               False                 False            False            False
# 3               False                 False            False            False
# 4               False                 False            False            False
# 5               False                 False            False            False
#
#             begging Name_s Address City State  ZIP Code Race_s Sex_s DOB_s  \
# Booking No
# 1             False    NaN     NaN  NaN   NaN       NaN    NaN   NaN   NaT
# 2             False    NaN     NaN  NaN   NaN       NaN    NaN   NaN   NaT
# 3             False    NaN     NaN  NaN   NaN       NaN    NaN   NaN   NaT
# 4             False    NaN     NaN  NaN   NaN       NaN    NaN   NaN   NaT
# 5             False    NaN     NaN  NaN   NaN       NaN    NaN   NaN   NaT
#
#            Booking Date  Booking Time Facility Location_s Arresting Agency_s  \
# Booking No
# 1                   NaT           NaN      NaN        NaN                NaN
# 2                   NaT           NaN      NaN        NaN                NaN
# 3                   NaT           NaN      NaN        NaN                NaN
# 4                   NaT           NaN      NaN        NaN                NaN
# 5                   NaT           NaN      NaN        NaN                NaN
#
#            Charge Title Charge Level
# Booking No
# 1             NaN   NaN          NaN
# 2             NaN   NaN          NaN
# 3             NaN   NaN          NaN
# 4             NaN   NaN          NaN
# 5             NaN   NaN          NaN

# %%
df_bookings_sheriff = df_bookings_sheriff.loc[:,~df_bookings_sheriff.columns.duplicated()]

# %%
df_bookings_sheriff['transient'] = ~df_bookings_sheriff['Name_s'].isnull()

# %%
droppable_columns = [x for x in df_bookings_sheriff.columns if x.endswith('_s')]

droppable_columns
# Out:
# ['Name_s', 'Race_s', 'Sex_s', 'DOB_s', 'Location_s', 'Arresting Agency_s']

# %%
df_bookings_sheriff.drop(droppable_columns + ['Charge', 'Title', 'Charge Level'], axis=1, inplace=True)

# %%
df_bookings_sheriff.to_csv('../data/bookings-with-transient-status.csv', index=False)
