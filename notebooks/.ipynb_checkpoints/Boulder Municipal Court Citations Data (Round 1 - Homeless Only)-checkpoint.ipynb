# %%
import pandas as pd

df = pd.read_excel('../data/DU LAW REQUEST.XLSX')

# %%
df.head()
# Out:
#            COURT_CASE      VIOLATION_DATE CURRENT_STREET_ADDRESS STATUTE_DESC  \
# 0  CR-2015-0000038-GE 2015-01-04 04:50:00                    YES  Trespassing
# 1  CR-2015-0000042-GE 2015-01-04 15:40:00                   NONE  Trespassing
# 2  CR-2015-0000046-GE 2015-01-03 23:58:00                    YES  Trespassing
# 3  CR-2015-0000047-GE 2015-01-01 15:43:00        2960 VALMONT RD  Trespassing
# 4  CR-2015-0000061-GE 2015-01-01 20:05:00                   NONE  Trespassing
#
#   STATUE_NUMBER                  LOCATION
# 0         5-4-3                 2900 IRIS
# 1         5-4-3  1800 28TH ST (MCDONALDS)
# 2         5-4-3              1905 15TH ST
# 3         5-4-3              3255 28TH ST
# 4         5-4-3              1650 30TH ST

# %%
print('''There are {} rows. The date range is {:%Y-%m-%d} to {:%Y-%m-%d}.

There are {} unique "court cases".
'''.format(
        df.shape[0],
        df.VIOLATION_DATE.min(),
        df.VIOLATION_DATE.max(),
        df.COURT_CASE.nunique(),
))
# Out:
# There are 4568 rows. The date range is 2015-01-01 to 2017-12-30.
#
# There are 3854 unique "court cases".

# %%
all_statute_counts = df.STATUTE_DESC.value_counts().to_frame()

# %% [markdown]
# 1. Can we find the number of charges that aren't bundled with other ones?
# 2. Which of sets of citations tend to go together?

# %%
# create a dataframe with only the citations that were given independently

onesies = df.groupby('COURT_CASE').first()[df.groupby('COURT_CASE').count().VIOLATION_DATE == 1].reset_index()

# %%
onesie_charges_merged = pd.merge(onesies.STATUTE_DESC.value_counts().to_frame(), all_statute_counts, how='inner', left_index=True, right_index=True, suffixes=('_onesies', '_all')).fillna(0).rename(columns={
        'STATUTE_DESC_onesies': 'count_onesies',
        'STATUTE_DESC_all': 'count_all',
    })
onesie_charges_merged['proportion_onesies'] = onesie_charges_merged['count_onesies'] / onesie_charges_merged['count_all']

# %%
onesie_charges_merged
# Out:
#                                                 count_onesies  count_all  \
# Trespassing                                              1252       1564
# Smoking Prohibited in Public Areas                        901        969
# Camping or Lodging on Property Without Consent            746        916
# Urinating in Public                                       251        347
# Tents And Nets Prohibited                                  82        104
# Trespassing on Public Property                             20         28
# Staying on Medians Prohibited                              11         12
# Using a Vehicle as a Residence                              9         11
# Aggressive Begging Prohibited                               6          8
# Obstructing Public Streets, Places - Buildings              3          6
#
#                                                 proportion_onesies
# Trespassing                                               0.800512
# Smoking Prohibited in Public Areas                        0.929825
# Camping or Lodging on Property Without Consent            0.814410
# Urinating in Public                                       0.723343
# Tents And Nets Prohibited                                 0.788462
# Trespassing on Public Property                            0.714286
# Staying on Medians Prohibited                             0.916667
# Using a Vehicle as a Residence                            0.818182
# Aggressive Begging Prohibited                             0.750000
# Obstructing Public Streets, Places - Buildings            0.500000

# %%
antihomeless_statutes = onesie_charges_merged.index.tolist()

# %%
only_antihomeless_encounters = df.groupby('COURT_CASE').filter(lambda group: group.STATUTE_DESC.isin(antihomeless_statutes).all())

print('''If we ask for encounters where someone was only given ONE citation (no matter what it is), we get {} records.

But if we ask for encounters where all the citations were antihomeless, we get {} records.

(Out of {} total unique encounters).
'''.format(
        onesies.shape[0],
        only_antihomeless_encounters.shape[0],
        df.COURT_CASE.nunique()
    ))
# Out:
# If we ask for encounters where someone was only given ONE citation (no matter what it is), we get 3281 records.
#
# But if we ask for encounters where all the citations were antihomeless, we get 3451 records.
#
# (Out of 3854 total unique encounters).

# %%
onesie_charges_merged
# Out:
#                                                 count_onesies  count_all  \
# Trespassing                                              1252       1564
# Smoking Prohibited in Public Areas                        901        969
# Camping or Lodging on Property Without Consent            746        916
# Urinating in Public                                       251        347
# Tents And Nets Prohibited                                  82        104
# Trespassing on Public Property                             20         28
# Staying on Medians Prohibited                              11         12
# Using a Vehicle as a Residence                              9         11
# Aggressive Begging Prohibited                               6          8
# Obstructing Public Streets, Places - Buildings              3          6
#
#                                                 proportion_onesies
# Trespassing                                               0.800512
# Smoking Prohibited in Public Areas                        0.929825
# Camping or Lodging on Property Without Consent            0.814410
# Urinating in Public                                       0.723343
# Tents And Nets Prohibited                                 0.788462
# Trespassing on Public Property                            0.714286
# Staying on Medians Prohibited                             0.916667
# Using a Vehicle as a Residence                            0.818182
# Aggressive Begging Prohibited                             0.750000
# Obstructing Public Streets, Places - Buildings            0.500000

# %%
antihomeless_charges_merged = pd.merge(all_statute_counts, only_antihomeless_encounters.STATUTE_DESC.value_counts().to_frame(), how='inner', left_index=True, right_index=True, suffixes=('_all', '_antihomeless')).fillna(0).rename(columns={
        'STATUTE_DESC_antihomeless': 'count_antihomeless',
        'STATUTE_DESC_all': 'count_all',
    })
antihomeless_charges_merged['count_onesies'] = onesie_charges_merged['count_onesies']
antihomeless_charges_merged['proportion_antihomeless'] = antihomeless_charges_merged['count_antihomeless'] / antihomeless_charges_merged['count_all']
antihomeless_charges_merged['proportion_onesies'] = onesie_charges_merged['proportion_onesies']

antihomeless_charges_merged
# Out:
#                                                 count_all  count_antihomeless  \
# Trespassing                                          1564                1324
# Smoking Prohibited in Public Areas                    969                 908
# Camping or Lodging on Property Without Consent        916                 815
# Urinating in Public                                   347                 260
# Tents And Nets Prohibited                             104                  91
# Trespassing on Public Property                         28                  23
# Staying on Medians Prohibited                          12                  12
# Using a Vehicle as a Residence                         11                   9
# Aggressive Begging Prohibited                           8                   6
# Obstructing Public Streets, Places - Buildings          6                   3
#
#                                                 count_onesies  \
# Trespassing                                              1252
# Smoking Prohibited in Public Areas                        901
# Camping or Lodging on Property Without Consent            746
# Urinating in Public                                       251
# Tents And Nets Prohibited                                  82
# Trespassing on Public Property                             20
# Staying on Medians Prohibited                              11
# Using a Vehicle as a Residence                              9
# Aggressive Begging Prohibited                               6
# Obstructing Public Streets, Places - Buildings              3
#
#                                                 proportion_antihomeless  \
# Trespassing                                                    0.846547
# Smoking Prohibited in Public Areas                             0.937049
# Camping or Lodging on Property Without Consent                 0.889738
# Urinating in Public                                            0.749280
# Tents And Nets Prohibited                                      0.875000
# Trespassing on Public Property                                 0.821429
# Staying on Medians Prohibited                                  1.000000
# Using a Vehicle as a Residence                                 0.818182
# Aggressive Begging Prohibited                                  0.750000
# Obstructing Public Streets, Places - Buildings                 0.500000
#
#                                                 proportion_onesies
# Trespassing                                               0.800512
# Smoking Prohibited in Public Areas                        0.929825
# Camping or Lodging on Property Without Consent            0.814410
# Urinating in Public                                       0.723343
# Tents And Nets Prohibited                                 0.788462
# Trespassing on Public Property                            0.714286
# Staying on Medians Prohibited                             0.916667
# Using a Vehicle as a Residence                            0.818182
# Aggressive Begging Prohibited                             0.750000
# Obstructing Public Streets, Places - Buildings            0.500000
